# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import *
from model.model import *
import PIL

# %%
chip_maker = ChipCreator(64)

# %%
im1 = chip_maker.make_chips('./raw/im1.tif')
im2 = chip_maker.make_chips('./raw/im2.tif')
# Out:
# /home/runrudy/Загрузки/project/utils.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(chip_list)

# %%
pred = Predictor('binary')

# %%
preds = []
for i in range(len(im1)):
    preds.append(pred(encode(im1[i][:,:,:3],im2[i][:,:,:3])))
preds = np.array(preds)

# %%
preds = preds.reshape(16,16,64,64).swapaxes(1,2).reshape(1024,1024)

# %%
plt.imshow(preds)
